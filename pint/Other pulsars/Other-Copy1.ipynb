# %%
import astropy.units as u
import matplotlib.pyplot as plt

import pint.fitter
from pint.models import get_model_and_toas
from pint.residuals import Residuals
import pint.logging

pint.logging.setup(level="INFO")
# Out:
# RuntimeWarning: This platform does not support extended precision floating-point, and PINT will run at reduced precision.
# 1

# %%
def plot_resids(m,t_all):
    rs = Residuals(t_all, m).phase_resids
    xt = t_all.get_mjds()
    plt.figure()
    plt.plot(xt, rs, "x")
    plt.title(f"{m.PSR.value} Pre-Fit Timing Residuals")
    plt.xlabel("MJD")
    plt.ylabel("Residual (phase)")
    plt.grid()

# %%
def calc(parfile,timfile,m,t_all,fitter="WLS"):
    m, t_all = get_model_and_toas(parfile, timfile)
    #plot_resids(m,t_all)
    if fitter=="WLS":
        f = pint.fitter.WLSFitter(t_all[:int(len(t_all)/2)], m)
        f.fit_toas(maxiter=100,debug=True)
        f2 = pint.fitter.WLSFitter(t_all[int(len(t_all)/2):], m)
        f2.fit_toas(maxiter=100,debug=True)

        f3 = pint.fitter.WLSFitter(t_all[:int(len(t_all)*3/4)], m)
        f3.fit_toas(maxiter=1000,debug=True)
        f4 = pint.fitter.WLSFitter(t_all[int(len(t_all)*1/4):], m)
        f4.fit_toas(maxiter=100,debug=True)
    if fitter=="GLS":
        f = pint.fitter.GLSFitter(t_all[:int(len(t_all)/2)], m)
        f.fit_toas(maxiter=100,debug=True)
        f2 = pint.fitter.GLSfitter(t_all[int(len(t_all)/2):], m)
        f2.fit_toas(maxiter=100,debug=True)

        f3 = pint.fitter.GLSFitter(t_all[:int(len(t_all)*3/4)], m)
        f3.fit_toas(maxiter=100,debug=True)
        f4 = pint.fitter.GLSFitter(t_all[int(len(t_all)*1/4):], m)
        f4.fit_toas(maxiter=100,debug=True)
    if fitter=="DownhillGLS":
        f = pint.fitter.DownhillGLSFitter(t_all[:int(len(t_all)/2)], m)
        f.fit_toas(maxiter=100,debug=True)
        f2 = pint.fitter.DownhillGLSitter(t_all[int(len(t_all)/2):], m)
        f2.fit_toas(maxiter=100,debug=True)

        f3 = pint.fitter.DownhillGLSFitter(t_all[:int(len(t_all)*3/4)], m)
        f3.fit_toas(maxiter=100,debug=True)
        f4 = pint.fitter.DownhillGLSFitter(t_all[int(len(t_all)*1/4):], m)
        f4.fit_toas(maxiter=100,debug=True)
    if fitter=="DownhillWLS":
        f = pint.fitter.DownhillWLSFitter(t_all[:int(len(t_all)/2)], m)
        f.fit_toas(maxiter=100,debug=True)
        f2 = pint.fitter.DownhillWLSitter(t_all[int(len(t_all)/2):], m)
        f2.fit_toas(maxiter=100,debug=True)

        f3 = pint.fitter.DownhillWLSFitter(t_all[:int(len(t_all)*3/4)], m)
        f3.fit_toas(maxiter=100,debug=True)
        f4 = pint.fitter.DownhillWLSFitter(t_all[int(len(t_all)*1/4):], m)
        f4.fit_toas(maxiter=100,debug=True)
        

    print("USING",parfile,"and", timfile)
    print("NToA:",len(t_all))
    print("First half:", "F0: ",f.model.F0.value, "F1:",f.model.F1.value)
    print("Second half:", "F0: ",f2.model.F0.value, "F1:",f2.model.F1.value)
    dt=(xt[int(len(t_all)/2)].value+xt[-1].value)/2-(xt[int(len(t_all)/2)].value+xt[0].value)/2
    n=1+(f.model.F0.value*f2.model.F1.value-f2.model.F0.value*f.model.F1.value)/(f.model.F1.value*f2.model.F1.value*dt*24*60*60)
    print("Braking index:", n)

    print("\n Now","with %50 overlap #####################")

    print("First half:", "F0: ",f3.model.F0.value, "F1:",f3.model.F1.value)
    print("Second half:", "F0: ",f4.model.F0.value, "F1:",f4.model.F1.value)
    dt2=(xt[int(len(t_all)/4)].value+xt[-1].value)/2-(xt[int(len(t_all)*3/4)].value+xt[0].value)/2
    n2=1+(f3.model.F0.value*f4.model.F1.value-f4.model.F0.value*f3.model.F1.value)/(f3.model.F1.value*f4.model.F1.value*dt*24*60*60)
    print("Braking index:", n2)

# %%
parfile= "J1534-5334.par"
timfile= "J1534-5334.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1534-5334.par and J1534-5334.tim
# NToA: 231
# First half: F0:  0.7305230274145181 F1: -7.62466988628397e-16
# Second half: F0:  0.7305230273278874 F1: -7.61010553299499e-16
# Braking index: 32816.369325283216
#
#  Now with %50 overlap #####################
# First half: F0:  0.7305230274142253 F1: -7.625294692079522e-16
# Second half: F0:  0.7305230274036314 F1: -7.62305872716383e-16
# Braking index: 5029.945262004013

# %%
parfile= "J1105-6107.par"
timfile= "J1105-6107.tim"

m, t_all = get_model_and_toas(parfile, timfile)
#plot_resids(m,t_all)
f = pint.fitter.WLSFitter(t_all[:int(len(t_all)/2)], m)
f.fit_toas(maxiter=100,debug=True)
f2 = pint.fitter.WLSFitter(t_all[int(len(t_all)/2):], m)
f2.fit_toas(maxiter=100,debug=True)

f3 = pint.fitter.WLSFitter(t_all[:int(len(t_all)*3/4)], m)
f3.fit_toas(maxiter=100,debug=True)
f4 = pint.fitter.WLSFitter(t_all[int(len(t_all)*1/4):], m)
f4.fit_toas(maxiter=100,debug=True)

print("USING",parfile,"and", timfile)
print("NToA:",len(t_all))
print("First half:", "F0: ",f.model.F0.value, "F1:",f.model.F1.value)
print("Second half:", "F0: ",f2.model.F0.value, "F1:",f2.model.F1.value)
dt=(xt[int(len(t_all)/2)].value+xt[-1].value)/2-(xt[int(len(t_all)/2)].value+xt[0].value)/2
n=1+(f.model.F0.value*f2.model.F1.value-f2.model.F0.value*f.model.F1.value)/(f.model.F1.value*f2.model.F1.value*dt*24*60*60)
print("Braking index:", n)

print("\n Now","with %50 overlap #####################")

print("First half:", "F0: ",f3.model.F0.value, "F1:",f3.model.F1.value)
print("Second half:", "F0: ",f4.model.F0.value, "F1:",f4.model.F1.value)
dt2=(xt[int(len(t_all)/4)].value+xt[-1].value)/2-(xt[int(len(t_all)*3/4)].value+xt[0].value)/2
n2=1+(f3.model.F0.value*f4.model.F1.value-f4.model.F0.value*f3.model.F1.value)/(f3.model.F1.value*f4.model.F1.value*dt*24*60*60)
print("Braking index:", n2)
# Out:
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1105-6107.par and J1105-6107.tim
# NToA: 145
# First half: F0:  15.822251577868007 F1: -3.966585255951625e-12
# Second half: F0:  15.822251477470985 F1: -3.965909845117753e-12
# Braking index: 13.156944280734477
#
#  Now with %50 overlap #####################
# First half: F0:  15.822251588773685 F1: -3.967285196045262e-12
# Second half: F0:  15.822251597537194 F1: -3.967618869587453e-12
# Braking index: -5.002439090510226

# %%
parfile= "J1709-4429.par"
timfile= "J1709-4429.tim"

m, t_all = get_model_and_toas(parfile, timfile)
#plot_resids(m,t_all)
f = pint.fitter.WLSFitter(t_all[:int(len(t_all)/2)], m)
f.fit_toas(maxiter=100,debug=True)
f2 = pint.fitter.WLSFitter(t_all[int(len(t_all)/2):], m)
f2.fit_toas(maxiter=100,debug=True)

f3 = pint.fitter.WLSFitter(t_all[:int(len(t_all)*3/4)], m)
f3.fit_toas(maxiter=100,debug=True)
f4 = pint.fitter.WLSFitter(t_all[int(len(t_all)*1/4):], m)
f4.fit_toas(maxiter=100,debug=True)

print("USING",parfile,"and", timfile)
print("NToA:",len(t_all))
print("First half:", "F0: ",f.model.F0.value, "F1:",f.model.F1.value)
print("Second half:", "F0: ",f2.model.F0.value, "F1:",f2.model.F1.value)
dt=(xt[int(len(t_all)/2)].value+xt[-1].value)/2-(xt[int(len(t_all)/2)].value+xt[0].value)/2
n=1+(f.model.F0.value*f2.model.F1.value-f2.model.F0.value*f.model.F1.value)/(f.model.F1.value*f2.model.F1.value*dt*24*60*60)
print("Braking index:", n)

print("\n Now","with %50 overlap #####################")

print("First half:", "F0: ",f3.model.F0.value, "F1:",f3.model.F1.value)
print("Second half:", "F0: ",f4.model.F0.value, "F1:",f4.model.F1.value)
dt2=(xt[int(len(t_all)/4)].value+xt[-1].value)/2-(xt[int(len(t_all)*3/4)].value+xt[0].value)/2
n2=1+(f3.model.F0.value*f4.model.F1.value-f4.model.F0.value*f3.model.F1.value)/(f3.model.F1.value*f4.model.F1.value*dt*24*60*60)
print("Braking index:", n2)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 0.932668'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -3.37633'
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\utils.py:2597 DegeneracyWarning: Parameter degeneracy found in designmatrix! The offending parameters are ['GLPH_1', 'GLF0_1', 'GLF1_1', 'GLF0D_1', 'GLTD_1'].
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLPH_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2197 RuntimeWarning: invalid value encountered in divide
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.47932839149316286*GLF0D_1 + 0.33746526250328507*GLF1_1 + 0.11221218335389621*GLTD_1 + 0.09884461386875092*GLPH_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.22876520186881524*GLF0_1 + -0.32708647998771195*GLPH_1 + -0.47843322603985455*GLF1_1 + -0.5059865773520617*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.935150001988153*GLF1_1 + 0.15834367448431166*GLF0_1 + 0.001631735547077098*GLPH_1 + -0.09426954909138299*GLF0D_1 + -1.0*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.7884721556901911*GLTD_1 + 0.2365203735014289*GLPH_1 + 0.11287256323355921*GLF0_1 + -0.07841894717436267*GLF1_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + -0.05714890655112735*GLF0D_1 + -0.20785273515187835*GLTD_1 + -0.2168165576353711*GLPH_1 + -0.5757047140590692*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.8091968982583343*GLTD_1 + 0.6505014965673843*GLF0D_1 + -0.09251572873300001*GLPH_1 + -0.39039441807197733*GLF0_1 + -1.0*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.41634212067554277*GLF0_1 + -0.36202055081492096*GLPH_1 + -0.5123358806396601*GLF1_1 + -0.6348038165375861*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 0
GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.1190347966297828e-07*GLTD_1 + -2.238748211246634e-07*GLF1_1 + -0.9999998900474565*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 2.2105299567005451e-07*GLTD_1 + -4.4211803420113195e-07*GLF1_1 + -0.9999997828757002*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999703318339*GLF0_1 + 6.007555532846239e-08*GLF1_1 + -2.991283073628868e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999970510290322*GLF0D_1 + 5.97738615048822e-06*GLF1_1 + 3.2040775315529834e-12*F1 + -1.807522195797394e-12*GLPH_1 + -2.095307857990411e-12*F0 + -2.9749066100762204e-06*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 5.7670915642837176e-08*GLTD_1 + -1.1531481757776502e-07*GLF1_1 + -0.9999999433261417*GLF0_1
# USING J1709-4429.par and J1709-4429.tim
# NToA: 114
# First half: F0:  9.754290027889123 F1: -8.85428227199037e-12
# Second half: F0:  9.754289907780645 F1: -8.844041741304182e-12
# Braking index: 23.828285227448276
#
#  Now with %50 overlap #####################
# First half: F0:  9.75429006637609 F1: -8.850281444323516e-12
# Second half: F0:  9.754289999558049 F1: -8.846981573022473e-12
# Braking index: 8.356926511235429

# %%
parfile= "J0742-2822.par"
timfile= "J0742-2822.tim"

m, t_all = get_model_and_toas(parfile, timfile)
#plot_resids(m,t_all)
f = pint.fitter.WLSFitter(t_all[:int(len(t_all)/2)], m)
f.fit_toas(maxiter=100,debug=True)
f2 = pint.fitter.WLSFitter(t_all[int(len(t_all)/2):], m)
f2.fit_toas(maxiter=100,debug=True)

f3 = pint.fitter.WLSFitter(t_all[:int(len(t_all)*3/4)], m)
f3.fit_toas(maxiter=100,debug=True)
f4 = pint.fitter.WLSFitter(t_all[int(len(t_all)*1/4):], m)
f4.fit_toas(maxiter=100,debug=True)

print("USING",parfile,"and", timfile)
print("NToA:",len(t_all))
print("First half:", "F0: ",f.model.F0.value, "F1:",f.model.F1.value)
print("Second half:", "F0: ",f2.model.F0.value, "F1:",f2.model.F1.value)
dt=(xt[int(len(t_all)/2)].value+xt[-1].value)/2-(xt[int(len(t_all)/2)].value+xt[0].value)/2
n=1+(f.model.F0.value*f2.model.F1.value-f2.model.F0.value*f.model.F1.value)/(f.model.F1.value*f2.model.F1.value*dt*24*60*60)
print("Braking index:", n)

print("\n Now","with %50 overlap #####################")

print("First half:", "F0: ",f3.model.F0.value, "F1:",f3.model.F1.value)
print("Second half:", "F0: ",f4.model.F0.value, "F1:",f4.model.F1.value)
dt2=(xt[int(len(t_all)/4)].value+xt[-1].value)/2-(xt[int(len(t_all)*3/4)].value+xt[0].value)/2
n2=1+(f3.model.F0.value*f4.model.F1.value-f4.model.F0.value*f3.model.F1.value)/(f3.model.F1.value*f4.model.F1.value*dt*24*60*60)
print("Braking index:", n2)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 21.4766'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -3.33962'
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J0742-2822.par and J0742-2822.tim
# NToA: 180
# First half: F0:  5.996127950777252 F1: -6.033843300866703e-13
# Second half: F0:  5.996127974412828 F1: -6.04762870882091e-13
# Braking index: -404.39141806815996
#
#  Now with %50 overlap #####################
# First half: F0:  5.996127948120405 F1: -6.03634989283366e-13
# Second half: F0:  5.996127959123947 F1: -6.044431361192259e-13
# Braking index: -236.68110084427636

# %%
parfile= "J0908-4913.par"
timfile= "J0908-4913.tim"

m, t_all = get_model_and_toas(parfile, timfile)
#plot_resids(m,t_all)
f = pint.fitter.WLSFitter(t_all[:int(len(t_all)/2)], m)
f.fit_toas(maxiter=100,debug=True)
f2 = pint.fitter.WLSFitter(t_all[int(len(t_all)/2):], m)
f2.fit_toas(maxiter=100,debug=True)

f3 = pint.fitter.WLSFitter(t_all[:int(len(t_all)*3/4)], m)
f3.fit_toas(maxiter=100,debug=True)
f4 = pint.fitter.WLSFitter(t_all[int(len(t_all)*1/4):], m)
f4.fit_toas(maxiter=100,debug=True)

print("USING",parfile,"and", timfile)
print("NToA:",len(t_all))
print("First half:", "F0: ",f.model.F0.value, "F1:",f.model.F1.value)
print("Second half:", "F0: ",f2.model.F0.value, "F1:",f2.model.F1.value)
dt=(xt[int(len(t_all)/2)].value+xt[-1].value)/2-(xt[int(len(t_all)/2)].value+xt[0].value)/2
n=1+(f.model.F0.value*f2.model.F1.value-f2.model.F0.value*f.model.F1.value)/(f.model.F1.value*f2.model.F1.value*dt*24*60*60)
print("Braking index:", n)

print("\n Now","with %50 overlap #####################")

print("First half:", "F0: ",f3.model.F0.value, "F1:",f3.model.F1.value)
print("Second half:", "F0: ",f4.model.F0.value, "F1:",f4.model.F1.value)
dt2=(xt[int(len(t_all)/4)].value+xt[-1].value)/2-(xt[int(len(t_all)*3/4)].value+xt[0].value)/2
n2=1+(f3.model.F0.value*f4.model.F1.value-f4.model.F0.value*f3.model.F1.value)/(f3.model.F1.value*f4.model.F1.value*dt*24*60*60)
print("Braking index:", n2)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 1.34321'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -6.98425'
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J0908-4913.par and J0908-4913.tim
# NToA: 173
# First half: F0:  9.366011252371933 F1: -1.3240475525055628e-12
# Second half: F0:  9.366011124152452 F1: -1.3222323551572896e-12
# Braking index: 174.79078973527945
#
#  Now with %50 overlap #####################
# First half: F0:  9.366011258029852 F1: -1.32613491110807e-12
# Second half: F0:  9.366011239080335 F1: -1.3250597099676258e-12
# Braking index: 103.56143384953702

# %%
parfile= "J1048-5832.par"
timfile= "J1048-5832.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 1.1366'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -3.98387'
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1048-5832.par and J1048-5832.tim
# NToA: 232
# First half: F0:  8.082418600737128 F1: -6.278758121287383e-12
# Second half: F0:  8.082418418181334 F1: -6.268905402949364e-12
# Braking index: 37.20675635566975
#
#  Now with %50 overlap #####################
# First half: F0:  8.082418610001405 F1: -6.2749254361380245e-12
# Second half: F0:  8.082418495306236 F1: -6.2704625059978294e-12
# Braking index: 17.406220774289228

# %%
parfile= "J1048-5832.par"
timfile= "J1048-5832.tim"

m, t_all = get_model_and_toas(parfile, timfile,"GLS")
calc(parfile,timfile,m,t_all)

# %%
parfile= "J1057-5226.par"
timfile= "J1057-5226.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 1.25986'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -4.20755'
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1057-5226.par and J1057-5226.tim
# NToA: 126
# First half: F0:  5.073188894410554 F1: -1.383338308366681e-13
# Second half: F0:  5.073188594295587 F1: -1.4937706440674515e-13
# Braking index: -48519.94173018616
#
#  Now with %50 overlap #####################
# First half: F0:  5.073188636814687 F1: -1.501857332394467e-13
# Second half: F0:  5.073188614659607 F1: -1.5011289785049213e-13
# Braking index: 294.3166990307688

# %%
parfile= "J1105-6107.par"
timfile= "J1105-6107.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1105-6107.par and J1105-6107.tim
# NToA: 145
# First half: F0:  15.822251577868007 F1: -3.966585255951625e-12
# Second half: F0:  15.822251477470985 F1: -3.965909845117753e-12
# Braking index: 13.156944280734477
#
#  Now with %50 overlap #####################
# First half: F0:  15.822251588773685 F1: -3.967285196045262e-12
# Second half: F0:  15.822251597537194 F1: -3.967618869587453e-12
# Braking index: -5.002439090510226

# %%
parfile= "J1253-5820.par"
timfile= "J1253-5820.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 0.864758'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -4.25682'
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1253-5820.par and J1253-5820.tim
# NToA: 204
# First half: F0:  3.9139267002463844 F1: -3.224782335910901e-14
# Second half: F0:  3.9139267007175054 F1: -3.2251176983219014e-14
# Braking index: -224.86270579722478
#
#  Now with %50 overlap #####################
# First half: F0:  3.913926700218333 F1: -3.224574200235827e-14
# Second half: F0:  3.91392670070473 F1: -3.225088724825172e-14
# Braking index: -345.55197281361

# %%
parfile= "J1534-5334.par"
timfile= "J1534-5334.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1534-5334.par and J1534-5334.tim
# NToA: 231
# First half: F0:  0.7305230274145181 F1: -7.62466988628397e-16
# Second half: F0:  0.7305230273278874 F1: -7.61010553299499e-16
# Braking index: 32816.369325283216
#
#  Now with %50 overlap #####################
# First half: F0:  0.7305230274142253 F1: -7.625294692079522e-16
# Second half: F0:  0.7305230274036314 F1: -7.62305872716383e-16
# Braking index: 5029.945262004013

# %%
parfile= "J1600-3053.par"
timfile= "J1600-3053.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 4
#       1 parfile= "J1600-3053.par"
#       2 timfile= "J1600-3053.tim"
# ----> 4 m, t_all = get_model_and_toas(parfile, timfile)
#       5 calc(parfile,timfile,m,t_all)
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:798, in get_model_and_toas(parfile, timfile, ephem, include_bipm, bipm_version, include_gps, planets, usepickle, tdb_method, include_pn, picklefilename, allow_name_mixing, limits, allow_tcb, add_tzr_to_model, **kwargs)
#     724 def get_model_and_toas(
#     725     parfile,
#     726     timfile,
#    (...)
#     740     **kwargs,
#     741 ):
#     742     """Load a timing model and a related TOAs, using model commands as needed
#     743
#     744     Parameters
#    (...)
#     795     A tuple with (model instance, TOAs instance)
#     796     """
# --> 798     mm = get_model(parfile, allow_name_mixing, allow_tcb=allow_tcb, **kwargs)
#     800     tt = get_TOAs(
#     801         timfile,
#     802         include_pn=include_pn,
#    (...)
#     812         limits=limits,
#     813     )
#     815     if "AbsPhase" not in mm.components and add_tzr_to_model:
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:712, in get_model(parfile, allow_name_mixing, allow_tcb, toas_for_tzr, **kwargs)
#     701     return model_builder(
#     702         StringIO(contents),
#     703         allow_name_mixing,
#    (...)
#     706         **kwargs,
#     707     )
#     709 # # parfile is a filename and can be handled by ModelBuilder
#     710 # if _model_builder is None:
#     711 #     _model_builder = ModelBuilder()
# --> 712 model = model_builder(
#     713     parfile,
#     714     allow_name_mixing,
#     715     allow_tcb=allow_tcb,
#     716     toas_for_tzr=toas_for_tzr,
#     717     **kwargs,
#     718 )
#     719 model.name = parfile
#     721 return model
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:187, in ModelBuilder.__call__(self, parfile, allow_name_mixing, allow_tcb, toas_for_tzr, **kwargs)
#     185 cps = [self.all_components.components[c] for c in selected]
#     186 tm = TimingModel(components=cps)
# --> 187 self._setup_model(
#     188     tm,
#     189     pint_param_dict,
#     190     original_name,
#     191     setup=True,
#     192     validate=True,
#     193     allow_tcb=allow_tcb_,
#     194 )
#     195 # Report unknown line
#     196 for k, v in unknown_param.items():
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:650, in ModelBuilder._setup_model(self, timing_model, pint_param_dict, original_name, setup, validate, allow_tcb)
#     648     timing_model.setup()
#     649 if validate:
# --> 650     timing_model.validate(allow_tcb=allow_tcb)
#     651 return timing_model
#
# File D:\miniconda3\Lib\site-packages\pint\models\timing_model.py:431, in TimingModel.validate(self, allow_tcb)
#     428     self.FINISH.frozen = True
#     430 for cp in self.components.values():
# --> 431     cp.validate()
#     433 self.validate_component_types()
#
# File D:\miniconda3\Lib\site-packages\pint\models\binary_dd.py:98, in BinaryDD.validate(self)
#      96 def validate(self):
#      97     """Validate the input parameters."""
# ---> 98     super().validate()
#      99     self.check_required_params(["T0", "A1"])
#     100     # If any *DOT is set, we need T0
#
# File D:\miniconda3\Lib\site-packages\pint\models\pulsar_binary.py:274, in PulsarBinary.validate(self)
#     270     raise ValueError(
#     271         f"Sine of inclination angle must be between zero and one ({self.SINI.quantity})"
#     272     )
#     273 if hasattr(self, "M2") and self.M2.value is not None and self.M2.value < 0:
# --> 274     raise ValueError(
#     275         f"Companion mass M2 cannot be negative ({self.M2.quantity})"
#     276     )
#     277 if (
#     278     hasattr(self, "ECC")
#     279     and self.ECC.value is not None
#     280     and not 0 <= self.ECC.value <= 1
#     281 ):
#     282     raise ValueError(
#     283         f"Eccentricity ECC must be between zero and one ({self.ECC.quantity})"
#     284     )
#
# ValueError: Companion mass M2 cannot be negative (-38.58763251641227 solMass)

# %%
parfile= "J1705-1906.par"
timfile= "J1705-1906.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 1.03058'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -6.90431'
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# USING J1705-1906.par and J1705-1906.tim
# NToA: 78
# First half: F0:  3.3445867929702575 F1: -4.6256775703884244e-14
# Second half: F0:  3.3445867927595847 F1: -4.624229351302136e-14
# Braking index: 406.2526463720741
#
#  Now with %50 overlap #####################
# First half: F0:  3.3445867929859525 F1: -4.625194330782207e-14
# Second half: F0:  3.344586792843199 F1: -4.624464808784441e-14
# Braking index: 205.15180041095945

# %%
parfile= "J1709-4429.par"
timfile= "J1709-4429.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'EPHVER 5'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEF 0.932668'
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:198 UserWarning: Unrecognized parfile line 'TNGLOBALEQ -3.37633'
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\observatory\clock_file.py:176 UserWarning: Data points out of range in clock file 'mo2gps.clk'
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\utils.py:2597 DegeneracyWarning: Parameter degeneracy found in designmatrix! The offending parameters are ['GLPH_1', 'GLF0_1', 'GLF1_1', 'GLF0D_1', 'GLTD_1'].
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLPH_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2197 RuntimeWarning: invalid value encountered in divide
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.47932839149316286*GLF0D_1 + 0.33746526250328507*GLF1_1 + 0.11221218335389621*GLTD_1 + 0.09884461386875092*GLPH_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.22876520186881524*GLF0_1 + -0.32708647998771195*GLPH_1 + -0.47843322603985455*GLF1_1 + -0.5059865773520617*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.935150001988153*GLF1_1 + 0.15834367448431166*GLF0_1 + 0.001631735547077098*GLPH_1 + -0.09426954909138299*GLF0D_1 + -1.0*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.7884721556901911*GLTD_1 + 0.2365203735014289*GLPH_1 + 0.11287256323355921*GLF0_1 + -0.07841894717436267*GLF1_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + -0.05714890655112735*GLF0D_1 + -0.20785273515187835*GLTD_1 + -0.2168165576353711*GLPH_1 + -0.5757047140590692*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.8091968982583343*GLTD_1 + 0.6505014965673843*GLF0D_1 + -0.09251572873300001*GLPH_1 + -0.39039441807197733*GLF0_1 + -1.0*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.41634212067554277*GLF0_1 + -0.36202055081492096*GLPH_1 + -0.5123358806396601*GLF1_1 + -0.6348038165375861*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 0.10290908759144755*GLTD_1 + -0.07139421590701442*GLPH_1 + -0.4465509288710304*GLF1_1 + -0.6056452758773453*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9413711145998144*GLF1_1 + 0.3460347204692034*GLF0_1 + 0.008169268458411809*GLPH_1 + -0.2936170038107995*GLF0D_1 + -1.0*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.4788289844911933*GLF0D_1 + 0.44516600119969735*GLF1_1 + 0.10470960489432295*GLPH_1 + 0.0003941009272675598*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.4994548972342561*GLF1_1 + 0.33634595461985134*GLF0_1 + 0.26999272226776405*GLF0D_1 + -0.14211327483056843*GLPH_1 + -1.0*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.0882913243515427*GLF0_1 + -0.0629727023028584*GLTD_1 + -0.2907435370048191*GLPH_1 + -0.8088425456651275*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.06612923358969025*GLTD_1 + -0.1396879820123423*GLPH_1 + -0.3989790678056401*GLF1_1 + -0.561754957913814*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.8875526166612596*GLF1_1 + 0.31606919868976174*GLF0D_1 + -0.03431905292657916*GLPH_1 + -0.1769116407002016*GLF0_1 + -1.0*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 0
GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.3479899591730245*GLTD_1 + -0.10863072317974722*GLPH_1 + -0.5595291683216107*GLF1_1 + -0.7060597850127619*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1 + 0.25870411069022503*GLPH_1 + -0.15043431759896062*GLF1_1 + -0.37401128928823263*GLF0_1 + -0.6681334636595428*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 0.4210087409868764*GLF1_1 + 0.02722272715764041*GLPH_1 + -0.4949646415026484*GLTD_1 + -0.9483895065008174*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.843217677677302*GLF0_1 + 0.4774066540973255*GLF0D_1 + -0.07966983401964464*GLTD_1 + -0.32602267926982076*GLPH_1 + -1.0*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1 + 0.1743843119493934*GLPH_1 + 0.01956618839273095*GLF0_1 + -0.45293460677317426*GLF1_1 + -0.6973302220014979*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 0.1186499273900271*GLTD_1 + -0.017821961369440052*GLPH_1 + -0.3037292043622142*GLF1_1 + -0.8041378009523935*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1 + 0.22614150452404536*GLPH_1 + -0.22633208602574958*GLF1_1 + -0.4202919436879773*GLF0D_1 + -0.5213359459978708*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.7063956988756321*GLF0D_1 + 0.24679233124091968*GLTD_1 + 0.23061475572119716*GLF0_1 + -0.24765128478425733*GLPH_1 + -1.0*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.7106841347875518*GLTD_1 + 0.2569250711443333*GLPH_1 + 0.20897211235808286*GLF1_1 + -0.10919377159938981*GLF0D_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF1_1 + 0.35861493398047367*GLF0D_1 + 0.02140320532198189*GLPH_1 + -0.4678294231655258*GLF0_1 + -0.9049618626603196*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + -0.03339093822218024*GLTD_1 + -0.20150857364803143*GLPH_1 + -0.2937706319835203*GLF0_1 + -0.5219540755578873*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.5545843648425345*GLF1_1 + -0.033355939826667055*GLPH_1 + -0.5365611793931435*GLTD_1 + -0.9903975355007276*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF1_1 + 0.42110022883248865*GLF0_1 + 0.07316648849687865*GLPH_1 + -0.6033339527420445*GLF0D_1 + -0.8726810132839307*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.8796400884868063*GLTD_1 + 0.6381612873860568*GLF1_1 + 0.4576998085645453*GLPH_1 + -0.8570640771396921*GLF0D_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 0.7027415333090099*GLF0D_1 + -0.41578423007195503*GLPH_1 + -0.5002377638764994*GLF1_1 + -0.8944634579765854*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.35506964283647985*GLTD_1 + -0.10750682462596167*GLPH_1 + -0.562347190237613*GLF1_1 + -0.7111516560262624*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.8772270652828044*GLTD_1 + 0.593493820066133*GLF0_1 + -0.024648658450480226*GLPH_1 + -0.45440967701398977*GLF0D_1 + -1.0*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1 + 0.5979831005100533*GLF0_1 + 0.07672771348345274*GLPH_1 + -0.8200409968102816*GLF1_1 + -0.8372684832159397*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.39006742269145356*GLTD_1 + -0.1806426992808639*GLPH_1 + -0.4004905577227406*GLF0_1 + -0.8542840540348051*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.6633059394913574*GLTD_1 + 0.3873961705110254*GLF1_1 + 0.3019255698973829*GLPH_1 + -0.27373757500617374*GLF0D_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1 + 0.036181013262107806*GLF0_1 + 0.014288586317541997*GLPH_1 + -0.12023636515342048*GLF0D_1 + -0.9273898210541491*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.534719124642598*GLF0D_1 + 0.24517630300304194*GLTD_1 + 0.15737546365096103*GLF1_1 + 0.08718827951228082*GLPH_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.30088602328638087*GLF0_1 + -0.3368117473618571*GLPH_1 + -0.44614560946036186*GLTD_1 + -0.6041776224187178*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + -0.014436720940096208*GLF0_1 + -0.22077688086274602*GLTD_1 + -0.2651294316915334*GLPH_1 + -0.567036366597001*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + -0.14901844215175608*GLF1_1 + -0.16836251311538264*GLPH_1 + -0.22553972840453296*GLF0D_1 + -0.5020440342185097*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLTD_1 + 0.28605576003645*GLF0_1 + 0.010735415089224274*GLPH_1 + -0.3234244627493452*GLF0D_1 + -0.9720317033675403*GLF1_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 0.6534249580992818*GLF1_1 + -0.045221098064214406*GLPH_1 + -0.6640378064027385*GLF0D_1 + -0.9574230840991904*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 0.019390443905118283*GLF0_1 + -0.09419400665533996*GLF1_1 + -0.2681260773813071*GLPH_1 + -0.7249366902029376*GLTD_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF1_1 + 0.2153486832695655*GLPH_1 + -0.01315906051839232*GLF0D_1 + -0.25163017946162813*GLTD_1 + -0.8933413103286882*GLF0_1
# ...
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 4.5991330972321565e-08*GLTD_1 + -9.21509230320146e-08*GLF1_1 + -0.999999954642392*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.3957624812410423e-07*GLTD_1 + -2.78993269991058e-07*GLF1_1 + -0.9999998630604018*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.3077946749343998e-07*GLTD_1 + -2.6155550615771094e-07*GLF1_1 + -0.9999998715529588*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999490098217*GLF0D_1 + 1.0360762946027052e-07*GLF1_1 + -5.1689687162751436e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999906432202*GLF0_1 + 2.1427574815832824e-08*GLF1_1 + -1.2290673925182567e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999131959124*GLF0D_1 + 1.767157078537069e-07*GLF1_1 + -8.833128514198922e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.7319478626506084e-08*GLTD_1 + -3.420970061931763e-08*GLF1_1 + -0.999999983426713*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 2.2321285413544345e-07*GLTD_1 + -4.4640852708332225e-07*GLF1_1 + -0.9999997807872562*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.1637665647620173e-06*GLTD_1 + -2.326260700478152e-06*GLF1_1 + -0.9999988582223129*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999804297607*GLF0_1 + 3.997266081094903e-08*GLF1_1 + -2.0075687144193562e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 3.695754119295648e-08*GLTD_1 + -7.399336132225983e-08*GLF1_1 + -0.999999963626193*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 3.990989419959509e-08*GLTD_1 + -7.956971176447369e-08*GLF1_1 + -0.9999999610564854*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 6.289345888225726e-08*GLTD_1 + -1.2604652531218478e-07*GLF1_1 + -0.9999999380014277*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999998959095685*GLF0D_1 + 2.121413731072676e-07*GLF1_1 + -1.0616021823751177e-07*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999177077382*GLF0D_1 + 1.67581349039958e-07*GLF1_1 + -8.379959213544253e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999677283344*GLF0D_1 + 6.545500288024001e-08*GLF1_1 + -3.2562045642123556e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999728021277*GLF0_1 + 5.4672522723590616e-08*GLF1_1 + -2.7075083081600735e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.999999504087453*GLF0D_1 + 1.0097455520985056e-06*GLF1_1 + -5.048346116294086e-07*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.999999973262589*GLF0_1 + 5.4581109426604176e-08*GLF1_1 + -2.7310000406328912e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999201759898*GLF0D_1 + 1.6250344872392668e-07*GLF1_1 + -8.123453313802828e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 2.224683771416912e-08*GLTD_1 + -4.4209916747246964e-08*GLF1_1 + -0.9999999784735039*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 2.3993678797525003e-08*GLTD_1 + -4.751765586203734e-08*GLF1_1 + -0.9999999769090808*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 6.401775589300777e-08*GLTD_1 + -1.282303774281826e-07*GLF1_1 + -0.9999999369485185*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.0049495463453038e-08*GLTD_1 + -1.6940706126107296e-08*GLF1_1 + -0.9999999920833154*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.999999956745257*GLF0_1 + 8.797476807735319e-08*GLF1_1 + -4.398916037263493e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999741403317*GLF0_1 + 5.2615276321329056e-08*GLF1_1 + -2.63092871259072e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 3.960313408341851e-08*GLTD_1 + -7.868141195917652e-08*GLF1_1 + -0.9999999615860353*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999998722641847*GLF0D_1 + 2.6020180978807105e-07*GLF1_1 + -1.301501120209314e-07*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999462598673*GLF0_1 + 1.0936042201787477e-07*GLF1_1 + -5.466837064947691e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999738460139*GLF0_1 + 5.370433273406864e-08*GLF1_1 + -2.7145963334546762e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999058548927*GLF0D_1 + 1.9158384578977683e-07*GLF1_1 + -9.572626685442834e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999500077044*GLF0D_1 + 1.0179932199770322e-07*GLF1_1 + -5.0910206001533073e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.4677070397176926e-07*GLTD_1 + -2.9353110094974853e-07*GLF1_1 + -0.9999998558457333*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 2.8502385201065706e-08*GLTD_1 + -5.68555694550752e-08*GLF1_1 + -0.9999999721712249*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 4.844616868739627e-08*GLTD_1 + -9.65941661261694e-08*GLF1_1 + -0.9999999527255423*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 1.931166880956424e-08*GLTD_1 + -3.8407195661688474e-08*GLF1_1 + -0.9999999811666666*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 1.4894624243384516e-08*GLTD_1 + -2.9037394663574264e-08*GLF1_1 + -0.9999999861588161*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999835452353*GLF0D_1 + 3.3601654539748314e-08*GLF1_1 + -1.6803610048008204e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.999999984442442*GLF0D_1 + 3.180844420284352e-08*GLF1_1 + -1.5976333568764043e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 6.19788513124444e-07*GLTD_1 + -1.239593028226627e-06*GLF1_1 + -0.9999993912399603*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 7.945979432528142e-07*GLTD_1 + -1.5891068302724216e-06*GLF1_1 + -0.9999992196505854*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 8.281654824436203e-08*GLTD_1 + -1.656155111647395e-07*GLF1_1 + -0.9999999187173251*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0_1 + 9.833658434863874e-08*GLTD_1 + -1.9673410536835613e-07*GLF1_1 + -0.9999999033694307*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999316920853*GLF0D_1 + 1.3903234212388563e-07*GLF1_1 + -6.94746083898064e-08*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 7.849307531379377e-08*GLTD_1 + -1.567326985951543e-07*GLF1_1 + -0.9999999231456814*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.2868256017030818e-07*GLTD_1 + -2.572355558422881e-07*GLF1_1 + -0.9999998737291464*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 1.1190347966297828e-07*GLTD_1 + -2.238748211246634e-07*GLF1_1 + -0.9999998900474565*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 2.2105299567005451e-07*GLTD_1 + -4.4211803420113195e-07*GLF1_1 + -0.9999997828757002*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999999703318339*GLF0_1 + 6.007555532846239e-08*GLF1_1 + -2.991283073628868e-08*GLTD_1 + -1.0*GLF0D_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 0.9999970510290322*GLF0D_1 + 5.97738615048822e-06*GLF1_1 + 3.2040775315529834e-12*F1 + -1.807522195797394e-12*GLPH_1 + -2.095307857990411e-12*F0 + -2.9749066100762204e-06*GLTD_1 + -1.0*GLF0_1
# WARNING  (pint.logging                  ): D:\miniconda3\Lib\site-packages\pint\fitter.py:2183 DegeneracyWarning: Parameter degeneracy; the following linear combination yields almost no change: 1.0*GLF0D_1 + 5.7670915642837176e-08*GLTD_1 + -1.1531481757776502e-07*GLF1_1 + -0.9999999433261417*GLF0_1
# USING J1709-4429.par and J1709-4429.tim
# NToA: 114
# First half: F0:  9.754290027889123 F1: -8.85428227199037e-12
# Second half: F0:  9.754289907780645 F1: -8.844041741304182e-12
# Braking index: 23.828285227448276
#
#  Now with %50 overlap #####################
# First half: F0:  9.75429006637609 F1: -8.850281444323516e-12
# Second half: F0:  9.754289999558049 F1: -8.846981573022473e-12
# Braking index: 8.356926511235429

# %%
parfile= "J2051-0827.par"
timfile= "J2051-0827.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# ---------------------------------------------------------------------------
# UnknownBinaryModel                        Traceback (most recent call last)
# Cell In[76], line 4
#       1 parfile= "J2051-0827.par"
#       2 timfile= "J2051-0827.tim"
# ----> 4 m, t_all = get_model_and_toas(parfile, timfile)
#       5 calc(parfile,timfile,m,t_all)
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:798, in get_model_and_toas(parfile, timfile, ephem, include_bipm, bipm_version, include_gps, planets, usepickle, tdb_method, include_pn, picklefilename, allow_name_mixing, limits, allow_tcb, add_tzr_to_model, **kwargs)
#     724 def get_model_and_toas(
#     725     parfile,
#     726     timfile,
#    (...)
#     740     **kwargs,
#     741 ):
#     742     """Load a timing model and a related TOAs, using model commands as needed
#     743
#     744     Parameters
#    (...)
#     795     A tuple with (model instance, TOAs instance)
#     796     """
# --> 798     mm = get_model(parfile, allow_name_mixing, allow_tcb=allow_tcb, **kwargs)
#     800     tt = get_TOAs(
#     801         timfile,
#     802         include_pn=include_pn,
#    (...)
#     812         limits=limits,
#     813     )
#     815     if "AbsPhase" not in mm.components and add_tzr_to_model:
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:712, in get_model(parfile, allow_name_mixing, allow_tcb, toas_for_tzr, **kwargs)
#     701     return model_builder(
#     702         StringIO(contents),
#     703         allow_name_mixing,
#    (...)
#     706         **kwargs,
#     707     )
#     709 # # parfile is a filename and can be handled by ModelBuilder
#     710 # if _model_builder is None:
#     711 #     _model_builder = ModelBuilder()
# --> 712 model = model_builder(
#     713     parfile,
#     714     allow_name_mixing,
#     715     allow_tcb=allow_tcb,
#     716     toas_for_tzr=toas_for_tzr,
#     717     **kwargs,
#     718 )
#     719 model.name = parfile
#     721 return model
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:171, in ModelBuilder.__call__(self, parfile, allow_name_mixing, allow_tcb, toas_for_tzr, **kwargs)
#     169     else:
#     170         remaining_args[k] = v
# --> 171 selected, conflict, param_not_in_pint = self.choose_model(pint_param_dict)
#     172 selected.update(set(self.default_components))
#     174 # Add SolarSystemShapiro only if an Astrometry component is present.
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:450, in ModelBuilder.choose_model(self, param_inpar)
#     448 if binary is not None:
#     449     binary = binary[0]
# --> 450     binary_cp = self.all_components.search_binary_components(binary)
#     451     selected_components.add(binary_cp.__class__.__name__)
#     452 # 2. Get the component list from the parameters in the parfile.
#     453 # 2.1 Check the aliases of input parameters.
#     454 # This does not include the repeating parameters, but it should not
#     455 # matter in the component selection.
#
# File D:\miniconda3\Lib\site-packages\pint\models\timing_model.py:3612, in AllComponents.search_binary_components(self, system_name)
#    3610     if system_name == self.components[cp_name].binary_model_name:
#    3611         return self.components[cp_name]
# -> 3612 raise UnknownBinaryModel(
#    3613     f"Pulsar system/Binary model component"
#    3614     f" {system_name} is not provided."
#    3615 )
#
# UnknownBinaryModel: Pulsar system/Binary model component T2 is not provided.

# %%
parfile= "J2241-5236.par"
timfile= "J2241-5236.tim"

m, t_all = get_model_and_toas(parfile, timfile)
calc(parfile,timfile,m,t_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 4
#       1 parfile= "J2241-5236.par"
#       2 timfile= "J2241-5236.tim"
# ----> 4 m, t_all = get_model_and_toas(parfile, timfile)
#       5 calc(parfile,timfile,m,t_all)
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:798, in get_model_and_toas(parfile, timfile, ephem, include_bipm, bipm_version, include_gps, planets, usepickle, tdb_method, include_pn, picklefilename, allow_name_mixing, limits, allow_tcb, add_tzr_to_model, **kwargs)
#     724 def get_model_and_toas(
#     725     parfile,
#     726     timfile,
#    (...)
#     740     **kwargs,
#     741 ):
#     742     """Load a timing model and a related TOAs, using model commands as needed
#     743
#     744     Parameters
#    (...)
#     795     A tuple with (model instance, TOAs instance)
#     796     """
# --> 798     mm = get_model(parfile, allow_name_mixing, allow_tcb=allow_tcb, **kwargs)
#     800     tt = get_TOAs(
#     801         timfile,
#     802         include_pn=include_pn,
#    (...)
#     812         limits=limits,
#     813     )
#     815     if "AbsPhase" not in mm.components and add_tzr_to_model:
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:712, in get_model(parfile, allow_name_mixing, allow_tcb, toas_for_tzr, **kwargs)
#     701     return model_builder(
#     702         StringIO(contents),
#     703         allow_name_mixing,
#    (...)
#     706         **kwargs,
#     707     )
#     709 # # parfile is a filename and can be handled by ModelBuilder
#     710 # if _model_builder is None:
#     711 #     _model_builder = ModelBuilder()
# --> 712 model = model_builder(
#     713     parfile,
#     714     allow_name_mixing,
#     715     allow_tcb=allow_tcb,
#     716     toas_for_tzr=toas_for_tzr,
#     717     **kwargs,
#     718 )
#     719 model.name = parfile
#     721 return model
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:187, in ModelBuilder.__call__(self, parfile, allow_name_mixing, allow_tcb, toas_for_tzr, **kwargs)
#     185 cps = [self.all_components.components[c] for c in selected]
#     186 tm = TimingModel(components=cps)
# --> 187 self._setup_model(
#     188     tm,
#     189     pint_param_dict,
#     190     original_name,
#     191     setup=True,
#     192     validate=True,
#     193     allow_tcb=allow_tcb_,
#     194 )
#     195 # Report unknown line
#     196 for k, v in unknown_param.items():
#
# File D:\miniconda3\Lib\site-packages\pint\models\model_builder.py:648, in ModelBuilder._setup_model(self, timing_model, pint_param_dict, original_name, setup, validate, allow_tcb)
#     646                     emt_par.use_alias = original_name[pp]
#     647 if setup:
# --> 648     timing_model.setup()
#     649 if validate:
#     650     timing_model.validate(allow_tcb=allow_tcb)
#
# File D:\miniconda3\Lib\site-packages\pint\models\timing_model.py:2826, in TimingModel.setup(self)
#    2824 """Run setup methods on all components."""
#    2825 for cp in self.components.values():
# -> 2826     cp.setup()
#
# File D:\miniconda3\Lib\site-packages\pint\models\pulsar_binary.py:201, in PulsarBinary.setup(self)
#     199 if any(v is not None for v in FBXs.values()):
#     200     if self.FB0.value is None:
# --> 201         raise ValueError("Some FBn parameters are set but FB0 is not.")
#     202     for fb_name, fb_value in FBXs.items():
#     203         self.binary_instance.add_binary_params(fb_name, fb_value)
#
# ValueError: Some FBn parameters are set but FB0 is not.
