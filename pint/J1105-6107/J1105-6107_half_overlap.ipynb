# %%
import astropy.units as u
import matplotlib.pyplot as plt

import pint.fitter
from pint.models import get_model_and_toas
from pint.residuals import Residuals
import pint.logging

pint.logging.setup(level="INFO")
# Out:
# RuntimeWarning: This platform does not support extended precision floating-point, and PINT will run at reduced precision.
# 1

# %%
parfile= "J1105-6107.par"
timfile= "J1105-6107_overlap2.tim"

m, t_all = get_model_and_toas(parfile, timfile)
m
# Out:
# WARNING  (pint.models.model_builder     ): UNITS is not specified. Assuming TDB...
# INFO     (pint.toa                      ): Using CLOCK = TT(TAI), so setting include_bipm = False
# TimingModel(
#   AbsPhase(
#     MJDParameter(   TZRMJD              57914.3295077349225347 (d) frozen=True),
#     strParameter(   TZRSITE             mo                frozen=True),
#     floatParameter( TZRFRQ              835.281006        (MHz) frozen=True)),
#   AstrometryEquatorial(
#     MJDParameter(   POSEPOCH            57600.0000000000000000 (d) frozen=True),
#     floatParameter( PX                  0.0               (mas) frozen=True),
#     AngleParameter( RAJ                 11:05:26.20662100 (hourangle) +/- 0h00m00.11789s frozen=False),
#     AngleParameter( DECJ                -61:07:48.03906000 (deg) +/- 0d00m00.80662s frozen=False),
#     floatParameter( PMRA                0.0               (mas / yr) frozen=True),
#     floatParameter( PMDEC               0.0               (mas / yr) frozen=True)),
#   DispersionDM(
#     floatParameter( DM                  271.01            (pc / cm3) +/- 0.02 pc / cm3 frozen=True),
#     floatParameter( DM1                 UNSET,
#     MJDParameter(   DMEPOCH             57600.0000000000000000 (d) frozen=True)),
#   PLRedNoise(
#     floatParameter( RNAMP               UNSET,
#     floatParameter( RNIDX               UNSET,
#     floatParameter( TNREDAMP            -8.94933          () frozen=True),
#     floatParameter( TNREDGAM            4.37021           () frozen=True),
#     floatParameter( TNREDC              8.0               () frozen=True)),
#   SolarSystemShapiro(
#     boolParameter(  PLANET_SHAPIRO      N                 frozen=True)),
#   SolarWindDispersion(
#     floatParameter( NE_SW               9.961             (1 / cm3) frozen=True),
#     floatParameter( SWP                 2.0               () frozen=True),
#     floatParameter( SWM                 0.0               () frozen=True)),
#   Spindown(
#     floatParameter( F0                  15.822251328775272 (Hz) +/- 1.75643007175e-09 Hz frozen=False),
#     MJDParameter(   PEPOCH              57600.0000000000000000 (d) frozen=True),
#     floatParameter( F1                  -3.966983884354932e-12 (Hz / s) +/- 6.856916223229575e-17 Hz / s frozen=False))
# )

# %%
rs = Residuals(t_all, m).phase_resids
xt = t_all.get_mjds()
plt.figure()
plt.plot(xt, rs, "x")
plt.title(f"{m.PSR.value} Pre-Fit Timing Residuals")
plt.xlabel("MJD")
plt.ylabel("Residual (phase)")
plt.grid()

# %%
t_all.print_summary()
# Out:
# Number of TOAs:  107
# Number of commands:  2
# Number of observatories: 1 ['most']
# MJD span:  57540.435 to 58422.939
# Date span: 2016-06-01 10:26:38.068969803 to 2018-10-31 22:31:50.178752052
# most TOAs (107):
#   Min freq:      834.519 MHz
#   Max freq:      835.442 MHz
#   Min error:     28.8 us
#   Max error:     1.03e+03 us
#   Median error:  96.8 us

# %%
error_ok = t_all.table["error"] <= 1000* u.us
t = t_all[error_ok]
t.print_summary()
# Out:
# Number of TOAs:  106
# Number of commands:  2
# Number of observatories: 1 ['most']
# MJD span:  57540.435 to 58422.939
# Date span: 2016-06-01 10:26:38.068969803 to 2018-10-31 22:31:50.178752052
# most TOAs (106):
#   Min freq:      834.519 MHz
#   Max freq:      835.442 MHz
#   Min error:     28.8 us
#   Max error:     809 us
#   Median error:  96.4 us

# %%
rs = Residuals(t, m).phase_resids
xt = t.get_mjds()
plt.figure()
plt.plot(xt, rs, "x")
plt.title(f"{m.PSR.value} Pre-Fit Timing Residuals")
plt.xlabel("MJD")
plt.ylabel("Residual (phase)")
plt.grid()

# %%
f = pint.fitter.Fitter.auto(t, m)
f.fit_toas()
# Out:
# INFO     (pint.fitter                   ): For narrowband TOAs with correlated errors and downhill fitter, returning 'DownhillGLSFitter'
# True

# %%
f.print_summary()
# Out:
# Fitted model using downhill_gls method with 4 free parameters to 106 TOAs
# Prefit residuals Wrms = 320765.1386041508 us, Postfit residuals Wrms = 8404.948402272663 us
# Chisq = 964.228 for 101 d.o.f. for reduced Chisq of 9.547
#
# PAR                   Prefit                  Postfit            Units
# ============== ==================== ============================ =====
# PSR                      J1105-6107 J1105-6107                   None
# TRACK                            -2 -2                           None
# EPHEM                         DE430 DE430                        None
# CLOCK                       TT(TAI) TT(TAI)                      None
# UNITS                           TDB TDB                          None
# START                       57360.8                      57540.4 d
# FINISH                      58422.9                      58422.9 d
# DILATEFREQ                        N                              None
# DMDATA                            N                              None
# NTOA                            145                              None
# CHI2                                                     964.228
# CHI2R                       4739.25                      9.54681
# TRES                        15566.4                      8404.95 us
# POSEPOCH                      57600                              d
# PX                                0                              mas
# RAJ                11h05m26.206621s  11h05m26.79642111s +/- 0.1 hourangle_second
# DECJ               -61d07m48.03906s  -61d07m45.30798951s +/- 0.94 arcsec
# PMRA                              0                              mas / yr
# PMDEC                             0                              mas / yr
# F0                          15.8223              15.822251596(6) Hz
# PEPOCH                        57600                              d
# F1                     -3.96698e-12           -3.96751(17)×10⁻¹² Hz / s
# PLANET_SHAPIRO                    N                              None
# NE_SW                         9.961                              1 / cm3
# SWP                               2
# SWM                               0
# DM                           271.01                              pc / cm3
# DMEPOCH                       57600                              d
# TZRMJD                      57914.3                              d
# TZRSITE                          mo mo                           None
# TZRFRQ                      835.281                              MHz
# TNREDAMP                   -8.94933
# TNREDGAM                    4.37021
# TNREDC                            8
#
# Derived Parameters:
# Period = 0.0632021298554181 s +/- 2.3280780635985873e-11 s
# Pdot = 1.5848274664665025e-14 +/- 6.989772693775488e-19
# Characteristic age = 6.319e+04 yr (braking index = 3)
# Surface magnetic field = 1.01e+12 G
# Magnetic field at light cylinder = 3.635e+04 G
# Spindown Edot = 2.478e+36 erg / s (I=1e+45 cm2 g)

# %%
nu1=15.8222515814
nu2=15.822251596
nudot1=-3.96722e-12
nudot2=-3.96751e-12
dt_days=(58422.9+57540.4)/2-(58338.2+57360.8)/2
dt=dt_days*24*60*60

# %%
n=1+(nu1*nudot2-nu2*nudot1)/(nudot1*nudot2*dt)
print(n)
# Out:
# -24.53145566673431
